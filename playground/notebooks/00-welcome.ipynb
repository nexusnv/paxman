# %% [markdown]
# # Welcome to the Paxman Jupyter Lab Playground
#
# **Paxman** is a contract-driven deterministic normalization engine for Python. It takes arbitrary input and a caller-owned contract, and produces an evidence-backed, replayable normalized artifact.
#
# This playground lets you explore Paxman interactively. Each notebook covers a specific feature.
#
# ## Notebooks
#
# | # | Topic | What you will learn |
# |---|---|---|
# | 00 | **Welcome** (this notebook) | Navigation, version check |
# | 01 | **Basics + Contracts** | Pydantic, JSON Schema, Dict DSL, OpenAPI |
# | 02 | **Capability: text_extraction** | Free-text field extraction |
# | 03 | **Capability: regex_extraction** | Pattern-based extraction |
# | 04 | **Capability: lookup** | ID/code-based lookup |
# | 05 | **Capability: inference** | AI-powered inference (V1 stub) |
# | 06 | **Capability: validation** | Constraint checking |
# | 07 | **Replay** | Deterministic replay hash |
# | 08 | **Money and Decimal** | First-class MONEY support |
# | 09 | **Full Pipeline** | End-to-end invoice normalization |
# | 10 | **Budget and Policy** | Cost control, PII protection |
#
# ## First-time setup
#
# If this is a fresh container build, run the cell below to verify Paxman is wired correctly.
#
# > **Note:** If you see 1.0.x here but your working tree is at v1.1.0+, you forgot to rebuild the image. Run `make playground-build && make playground-down && make playground-up` from the repo root.

# %%
import paxman

print(f"Paxman version: {paxman.__version__}")

# %% [markdown]
# ## How to use the playground
#
# 1. Start with **01-basics-contracts** to see how contracts work.
# 2. Browse **02-06** for individual capabilities.
# 3. Run **09-full-pipeline-invoice** first, then **07-replay** to see determinism in action.
# 4. **08-money-and-decimal** and **10-budget-and-policy** cover advanced features.
#
# To rebuild the image with latest source code:
# ```bash
# make playground-build && make playground-down && make playground-up
# ```
#
# **Tip:** The kernel is connected to a venv with paxman installed from source. If you edit src/paxman/ in the host repo, rebuild the image to pick up changes.
